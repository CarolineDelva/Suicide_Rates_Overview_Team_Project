# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#filepath
suicide_df = pd.read_csv("suicide_rates_project.csv")

# %%
suicide_df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
suicide_df.drop(columns='HDI for year')
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# 5         Albania  1987  female    75+ years            1       35600
# 6         Albania  1987  female  35-54 years            6      278800
# 7         Albania  1987  female  25-34 years            4      257200
# 8         Albania  1987    male  55-74 years            1      137500
# 9         Albania  1987  female   5-14 years            0      311000
# 10        Albania  1987  female  55-74 years            0      144600
# 11        Albania  1987    male   5-14 years            0      338200
# ...

# %%
suicide_df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
#How did suicide rates progress overtime in different countries?
suicide_new_df = suicide_df[['country', 'year', 'suicides_no']].groupby(['country', 'year']).agg({ 'suicides_no': 'sum'})
suicide_new_df
# Out:
#                           suicides_no
# country             year
# Albania             1987           73
#                     1988           63
#                     1989           68
#                     1992           47
#                     1993           73
#                     1994           50
#                     1995           88
#                     1996           89
#                     1997          170
#                     1998          154
#                     1999          139
#                     2000           54
#                     2001          119
#                     2002          133
#                     2003          124
#                     2004          146
#                     2005            0
#                     2006            0
#                     2007          124
#                     2008          160
#                     2009            0
#                     2010           96
# Antigua and Barbuda 1985            0
# ...

# %%
suicide_df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
#suicide rates in different countries
suicide_new_df2 = suicide_df[['country', 'suicides_no']].groupby(['country']).agg({ 'suicides_no': 'sum'})
suicide_new_df2
# Out:
#                               suicides_no
# country
# Albania                              1970
# Antigua and Barbuda                    11
# Argentina                           82219
# Armenia                              1905
# Aruba                                 101
# Australia                           70111
# Austria                             50073
# Azerbaijan                           1656
# Bahamas                                93
# Bahrain                               463
# Barbados                              177
# Belarus                             59892
# Belgium                             62761
# Belize                                348
# Bosnia and Herzegovina                318
# Brazil                             226613
# Bulgaria                            36388
# Cabo Verde                             42
# Canada                             107561
# Chile                               40895
# Colombia                            53080
# ...
